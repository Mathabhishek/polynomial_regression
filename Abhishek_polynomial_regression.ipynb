# %% [markdown]
# <a href="https://colab.research.google.com/github/Mathabhishek/polynomial_regression/blob/main/Abhishek_polynomial_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Polynomial Regression

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np #to work with arrays
import pandas as pd #to work with data set
import matplotlib.pyplot as plt #to visualize the data

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv('Corn_Yield.csv')
x = dataset.iloc[: , :-1].values
y = dataset.iloc[: , -1].values

# %% [markdown]
# ## Training the Linear Regression model on the whole dataset

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(x,y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Training the Polynomial Regression model on the whole dataset

# %%
from sklearn.preprocessing import PolynomialFeatures
pf = PolynomialFeatures(degree = 2)
x_poly = pf.fit_transform(x)
poly_reg = LinearRegression()
poly_reg.fit(x_poly, y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Visualising the Linear Regression results

# %%
plt.scatter(x,y , color = 'blue')
plt.plot(x, lin_reg.predict(x), color= 'red')
plt.title("Linear regression for crop yield ")
plt.xlabel("Fertilizer used ")
plt.ylabel("Corn Yield ")
plt.show()

# %% [markdown]
# ## Visualising the Polynomial Regression results

# %%
plt.scatter(x,y , color = 'blue')
plt.plot(x, poly_reg.predict(x_poly), color='red')
plt.title("polynomial regression for crop yield ")
plt.xlabel("Fertilizer used ")
plt.ylabel("Corn Yield ")
plt.show()

# %% [markdown]
# ## Predicting a new result with Linear Regression

# %%
lin_reg.predict([[6.5]])
# Out:
# array([-33.19744314])

# %% [markdown]
# ## Predicting a new result with Polynomial Regression

# %%
poly_reg.predict(pf.fit_transform([[6.5]]))
# Out:
# array([15.23318722])
